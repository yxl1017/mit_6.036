# %%
from code_for_lab11 import test_word

# %%
words = ["aaaaaaaaaa", "aabaaabbaaaababaabaa", "abcdefghijklmnopqrstuvwxyz", "abcabcabcabcabc"]
steps = [1000, 5000, 10000, 15000, 20000]

# %%
for step in steps[:3]:
    test_word(words[0], num_steps=step)
# Out:
# 1/10: training error 0.4720275501899327
# 2/10: training error 0.30973569648234633
# 3/10: training error 0.3050414339794772
# 4/10: training error 0.30447374727499993
# 5/10: training error 0.30393583952284603
# 6/10: training error 0.3031282217630478
# 7/10: training error 0.30184291192632506
# 8/10: training error 0.3000943416029644
# 9/10: training error 0.2958124983020975
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaaaa
# aaaa
# aaaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaa
# aaaaaaaa
# aaaaaaaaa
# aaaa
# aaaaaaa
# aaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaa
# aaaaa
# aaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaaaa
# aaaaaaa
# aaaaaaaaaaaa
# aaa
# aaaaaaaaaa
# aaaa
# aaaaaa
# aaaaaaaa
# aaaaaaaa
# aaaaaaa
# ...

# %%
for step in steps[:2]:
    test_word(words[0], num_hidden=2, num_steps=step)
# Out:
# 1/10: training error 0.4349449508164699
# 2/10: training error 0.30691345878283033
# 3/10: training error 0.30477190922536207
# 4/10: training error 0.302590684602375
# 5/10: training error 0.29995374900355687
# 6/10: training error 0.29635867815362693
# 7/10: training error 0.1874312385029195
# 8/10: training error 0.06629622539957597
# 9/10: training error 0.041536387580128134
# aaaaaaaaaa
# aaaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaa
# aaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# ...

# %%
for i in range(5, 15, 3):
    test_word(words[0], num_hidden=i, num_steps=steps[0])
# Out:
# 1/10: training error 0.40299003624902546
# 2/10: training error 0.306576900967599
# 3/10: training error 0.27863244000369763
# 4/10: training error 0.05702632465092639
# 5/10: training error 0.01105443643183035
# 6/10: training error 0.005358125045275068
# 7/10: training error 0.00330508267229956
# 8/10: training error 0.002285455888622602
# 9/10: training error 0.001691092674443794
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# aaaaaaaaaa
# ...

# %%
test_word(words[1], num_hidden=10, num_steps=steps[-1])
# Out:
# 1/10: training error 0.2105441753896555
# 2/10: training error 0.10574757837270699
# 3/10: training error 0.003228618023133591
# 4/10: training error 0.0006792282030046528
# 5/10: training error 0.018016364585445966
# 6/10: training error 0.03762600474294715
# 7/10: training error 0.002799667230015544
# 8/10: training error 0.0004006343120625965
# 9/10: training error 0.0001005794780595844
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# ...

# %%
test_word(words[1], num_hidden=14, num_steps=steps[-2])
# Out:
# 1/10: training error 0.15712133900204073
# 2/10: training error 0.0016676067036182865
# 3/10: training error 0.0003180993781099089
# 4/10: training error 9.436304166791996e-05
# 5/10: training error 3.405186417757115e-05
# 6/10: training error 1.3362993422715284e-05
# 7/10: training error 5.54791601390392e-06
# 8/10: training error 2.3865596330294142e-06
# 9/10: training error 1.0516717444481302e-06
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# ...

# %%
for s in steps[:3]:
    test_word(words[1], num_hidden=20, num_steps=s)
# Out:
# 1/10: training error 0.7801076388379132
# 2/10: training error 0.27779644789864044
# 3/10: training error 0.06386811229868435
# 4/10: training error 0.05254778760771151
# 5/10: training error 0.06149948195129591
# 6/10: training error 0.010976080527974582
# 7/10: training error 0.007180256274874503
# 8/10: training error 0.005128375222600199
# 9/10: training error 0.0038616335706505994
# aabaaabbaaaaba
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaaabbaaaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# aabaaabbaaaababaabaa
# ...

# %%
test_word(words[3], num_hidden=2, num_steps=steps[-1])
# Out:
# 1/10: training error 0.263452470193893
# 2/10: training error 0.09032662961165192
# 3/10: training error 0.05040873875311057
# 4/10: training error 0.005550518898815821
# 5/10: training error 0.01340316221762378
# 6/10: training error 0.0011014790506558953
# 7/10: training error 0.013744111156425357
# 8/10: training error 0.0006471850193303985
# 9/10: training error 0.00035545722285453023
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# ...

# %%
test_word(words[3], num_hidden=3)
# Out:
# 1/10: training error 0.2760553736929844
# 2/10: training error 0.16219709514353656
# 3/10: training error 0.15805399912610735
# 4/10: training error 0.1493197049903212
# 5/10: training error 0.14347879255860282
# 6/10: training error 0.14100512835099877
# 7/10: training error 0.13684156456367136
# 8/10: training error 0.0238338676831932
# 9/10: training error 0.0010842813173736724
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# abcabcabcabcabc
# ...

# %%
test_word(words[2], num_hidden=5, num_steps=steps[-1])
# Out:
# 1/10: training error 0.29606270979071025
# 2/10: training error 0.006594243068880219
# 3/10: training error 0.0017017043420527015
# 4/10: training error 0.0005643928864869498
# 5/10: training error 0.00019843404505470895
# 6/10: training error 7.160664672267296e-05
# 7/10: training error 2.6270631150467567e-05
# 8/10: training error 9.683559322401258e-06
# 9/10: training error 3.5475955370182814e-06
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# ...

# %%
test_word(words[2], num_hidden=3, num_steps=steps[-1])
# Out:
# 1/10: training error 0.9485467499948248
# 2/10: training error 0.21495643948575982
# 3/10: training error 0.04728624300821654
# 4/10: training error 0.011715700311089207
# 5/10: training error 0.0039162390959736485
# 6/10: training error 0.00237828810049444
# 7/10: training error 0.0008539093276513248
# 8/10: training error 0.00043174494617408994
# 9/10: training error 0.00023516591835492866
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# ...

# %%
for s in steps[:3]:
    test_word(words[2], num_hidden=5, num_steps=s)
# Out:
# 1/10: training error 2.7349715670494534
# 2/10: training error 1.2211766454761739
# 3/10: training error 0.6540856882518414
# 4/10: training error 0.406566373732019
# 5/10: training error 0.27432586320161595
# 6/10: training error 0.19724554232895175
# 7/10: training error 0.13824494543077306
# 8/10: training error 0.101956128127839
# 9/10: training error 0.07932548242075575
# abcdefghijklmnophr
# abbdefghijklmnopqrstuvwxyz
# abcdufghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abcdefghijkxyzstuvwxyz
# abcdefghijklmnopqrstuvwlcfghijklmnopqrstuvwxyz
# abcdefghijklklmnopqrstuvwxyz
# abcdefghijklmnowjmnopqrstuvwxyz
# abcdefghijklmno
# abstuvwxyz
# abcdefghxyz
# qbcdefghijklmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# abckxyz
# abcdefxqrstuvwijklmnopqrstuvwxyz
# abbdefgo
# abcdefghijklmnopqrsdklmnopqrstuvwxyz
# abcfijkxyz
# abcdefghijklmnopgpbcdefghijklzxyzpyz
# zbtuvwlmnopqrstuvhxqrstuvwxyz
# abdefghijklmnopqrstuvwxyzstuvwlmnopqrstuvwxyz
# abcdefghijklmnopqrstuvwxyz
# a
# ...

# %%
from code_for_lab11 import test_class_names
test_class_names(interactive = True, interactive_top5 = False, split=0, num_hidden = 150, num_steps = 20000, step_size = .001, train=True)
# Out:
# 1/10: training error 2.7957569368081043
# 2/10: training error 2.003678590524987
# 3/10: training error 1.6755070928040523
# 4/10: training error 1.4597819549222062
# 5/10: training error 1.3604785338736074
# 6/10: training error 1.2644620500394592
# 7/10: training error 1.1876477796133103
# 8/10: training error 1.166771608957882
# 9/10: training error 1.1181129417970328
# Starting string:  Intro
# Introduction to Biomedical Control
# Starting string:  intro
# introduction to Biomalate Stody in Biological Engineering and Contures
# Starting string:  ma
# manations of Planetalism and Control
# Starting string:  Ma
# Materials and Policy and Politics and Contures
# Starting string:  Ma
# Materials and Policy and Politics and Contures
# Starting string:  Mac
# Macromalysion and Computational Chemistry
# Starting string:  mac
# macrial Science
# Starting string:  .
# .onding Communication
# Starting string:  com
# comertation and Control
# Starting string:  Com
# Computational Chemistry
# ...

# %%
test_class_names(interactive = True, interactive_top5 = False, split=0, num_hidden = 150, num_steps = 50000, step_size = .001, train=True)
# Out:
# 1/10: training error 2.1639332131967532
# 2/10: training error 1.4067364340922457
# 3/10: training error 1.2128699977453499
# 4/10: training error 1.1084373542515953
# 5/10: training error 1.050324427452256
# 6/10: training error 1.011348284440972
# 7/10: training error 0.9635744090394784
# 8/10: training error 0.9486899145829634
# 9/10: training error 0.9209480578752182
# Starting string:  Com
# Computer Science and Processes
# Starting string:  Intro
# Introduction to Prevention
# Starting string:  com
# comectres
# Starting string:  intro
# introphysic Geometry
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 test_class_names(interactive = True, interactive_top5 = False, split=0, num_hidden = 150, num_steps = 50000, step_size = .001, train=True)
#
# ...

# %%
test_class_names(interactive = True, interactive_top5 = True, split=0, num_hidden = 150, num_steps = 20000, step_size = .001, train=True)
# Out:
# 1/10: training error 2.746699085102928
# 2/10: training error 1.953897419052364
# 3/10: training error 1.6304747884226494
# 4/10: training error 1.4487029215098988
# 5/10: training error 1.354278255272988
# 6/10: training error 1.278312226033387
# 7/10: training error 1.20398082249903
# 8/10: training error 1.192981073973904
# 9/10: training error 1.126648912793175
# Starting string:  Com
# Computational Materials and Seminar in American Chemistry
# Starting string:  com
# comeronal Methods and Applitations
# Starting string:  Intro
# Introduction to Applications
# Starting string:  intro
# introluction to Applications
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test_class_names(interactive = True, interactive_top5 = True, split=0, num_hidden = 150, num_steps = 20000, step_size = .001, train=True)
#
# ...

# %%
from code_for_lab11 import test_company_names
test_company_names(interactive = True, interactive_top5 = True, split=0, num_hidden = 150, num_steps = 50000, step_size = .001, train=True)
# Out:
# 1/10: training error 2.8909088571701917
# 2/10: training error 2.537097735816695
# 3/10: training error 2.4379269162597685
# 4/10: training error 2.374785358893113
# 5/10: training error 2.340688191466052
# 6/10: training error 2.319119411761732
# 7/10: training error 2.278432456254795
# 8/10: training error 2.2638546119374374
# 9/10: training error 2.255167141307016
# Starting string:  a
# and Solutions
# Starting string:  b
# berico Technologies
# Starting string:  B
# Bigital Company
# Starting string:  A
# Alling Technologies
# Starting string:  T
# Trude Technologies
# Starting string:  t
# tero Technologies
# Starting string:  interactive
# interactive Technologies
# Starting string:  Wh
# White Technologies
# Starting string:  Max
# Maxire Technologies
